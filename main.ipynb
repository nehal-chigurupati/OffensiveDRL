# %%
import pandas as pd
from utils.TrackingObjects import *

# %%
data = pd.read_json("TrackingData/0021500001.json")

# %%
curr_game = Game(data)

# %%
print(curr_game.events)
# Out:
# [<utils.TrackingObjects.Event object at 0x2bcce0510>, <utils.TrackingObjects.Event object at 0x2bcd10890>, <utils.TrackingObjects.Event object at 0x28006ba10>, <utils.TrackingObjects.Event object at 0x28011b050>, <utils.TrackingObjects.Event object at 0x28014bf10>, <utils.TrackingObjects.Event object at 0x280231ed0>, <utils.TrackingObjects.Event object at 0x280321cd0>, <utils.TrackingObjects.Event object at 0x2803dd750>, <utils.TrackingObjects.Event object at 0x2804c9550>, <utils.TrackingObjects.Event object at 0x280231e50>, <utils.TrackingObjects.Event object at 0x280663710>, <utils.TrackingObjects.Event object at 0x280711b50>, <utils.TrackingObjects.Event object at 0x2807dec50>, <utils.TrackingObjects.Event object at 0x2808a5410>, <utils.TrackingObjects.Event object at 0x28092ed90>, <utils.TrackingObjects.Event object at 0x2809b4710>, <utils.TrackingObjects.Event object at 0x280a46090>, <utils.TrackingObjects.Event object at 0x280ae7910>, <utils.TrackingObjects.Event object at 0x28
# ...

# %%
for event in curr_game.events
